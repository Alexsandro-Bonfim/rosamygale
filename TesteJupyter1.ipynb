# %%
import pandas as pd

url = "https://raw.githubusercontent.com/Alexsandro-Bonfim/rosamygale/main/Sales.csv"

# Carregar o arquivo CSV usando o Pandas
df = pd.read_csv(url)

# Exibir os dados como uma tabela
print(df)
# Out:
#     Channel Type Pay Type Item Category  Item ID Item code Item Name  \
# 0         Online    Debit   Electronics       10        P1    Laptop
# 1         Online    Debit   Electronics       10        P1    Laptop
# 2         Online    Debit   Electronics       10        P1    Laptop
# 3         Online    Debit   Electronics       10        P1    Laptop
# 4         Online   Credit   Electronics       14        P2       DVD
# ..           ...      ...           ...      ...       ...       ...
# 111         Post      DHL      Cellular       38        P6   Verizon
# 112         Post      DHL      Cellular       38        P6   Verizon
# 113         Post      DHL      Cellular       38        P6   Verizon
# 114         Post      DHL      Cellular       38        P6   Verizon
# 115         Post      DHL      Cellular       38        P6   Verizon
#
#      Employee ID Employee Code     Employee Name Employee Locations  ...  \
# ...

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/Alexsandro-Bonfim/rosamygale/main/Sales.csv"
dataframe = pd.read_csv(url, sep=';')

dataframe
# Out:
#     Channel Type,Pay Type,Item Category,Item ID,Item code,Item Name,Employee ID,Employee Code,Employee Name,Employee Locations,Employee Country,Manager,Department,Sales Date,Sales_Cost,Sales_Amt,Sales_Qty,Sales Type,Customer ID,Customer Name,Customer Location,Customer Country
# 0    Online,Debit,Electronics,10,P1,Laptop,1,E1,Sac...
# 1    Online,Debit,Electronics,10,P1,Laptop,2,E2,Rah...
# 2    Online,Debit,Electronics,10,P1,Laptop,3,E3,Sau...
# 3    Online,Debit,Electronics,10,P1,Laptop,4,E4,Moh...
# 4    Online,Credit,Electronics,14,P2,DVD,5,E5,Rahul...
# ..                                                 ...
# 111  Post,DHL,Cellular,38,P6,Verizon,25,E25,Jeffery...
# 112  Post,DHL,Cellular,38,P6,Verizon,26,E26,Javed,I...
# 113  Post,DHL,Cellular,38,P6,Verizon,27,E27,Hulk Ho...
# 114  Post,DHL,Cellular,38,P6,Verizon,28,E28,Mustaq ...
# 115  Post,DHL,Cellular,38,P6,Verizon,29,E29,Kaushik...
#
# [116 rows x 1 columns]

# %%
pip install dash plotly
# Out:
# ...
#   Obtaining dependency information for dash from https://files.pythonhosted.org/packages/7b/62/438626ab498869249e99376684ba6d88931e7c2dd86d03a92d9d7a9b4c54/dash-2.14.2-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for ansi2html from https://files.pythonhosted.org/packages/42/d7/1bc3433a2406b891182c25a7926abe3eb19af5870d540375ebf7795885b3/ansi2html-1.9.1-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.2 MB 1.4 MB/s eta 0:00:08
#    ---------------------------------------- 0.1/10.2 MB 656.4 kB/s eta 0:00:16
#    ---------------------------------------- 0.1/10.2 MB 939.4 kB/s eta 0:00:11
#     --------------------------------------- 0.2/10.2 MB 1.1 MB/s eta 0:00:10
#     --------------------------------------- 0.2/10.2 MB 1.3 MB/s eta 0:00:08
#    - -------------------------------------- 0.3/10.2 MB 1.3 MB/s eta 0:00:08
# ...

# %%
pip install jupyter_dash dash pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ipywidgets matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import ipywidgets as widgets
from ipywidgets import interact
import matplotlib.pyplot as plt

# Carregar o arquivo CSV usando o Pandas
url = "https://raw.githubusercontent.com/Alexsandro-Bonfim/rosamygale/main/Sales.csv"
df = pd.read_csv(url)

# Função para exibir dados com base nas categorias selecionadas
def show_data(employee_id=True, employee_code=True, employee_name=True, pay_type=True, item_category=True):
    selected_columns = []
    
    if employee_id:
        selected_columns.append('Employee ID')
    if employee_code:
        selected_columns.append('Employee Code')
    if employee_name:
        selected_columns.append('Employee Name')
    if pay_type:
        selected_columns.append('Pay Type')
    if item_category:
        selected_columns.append('Item Category')
    
    # Exibir os dados selecionados
    display(df[selected_columns])

# Criar widgets interativos para seleção de categorias
employee_id_checkbox = widgets.Checkbox(value=True, description='Employee ID')
employee_code_checkbox = widgets.Checkbox(value=True, description='Employee Code')
employee_name_checkbox = widgets.Checkbox(value=True, description='Employee Name')
pay_type_checkbox = widgets.Checkbox(value=True, description='Pay Type')
item_category_checkbox = widgets.Checkbox(value=True, description='Item Category')

# Criar a interface interativa usando a função interact
interact(show_data,
         employee_id=employee_id_checkbox,
         employee_code=employee_code_checkbox,
         employee_name=employee_name_checkbox,
         pay_type=pay_type_checkbox,
         item_category=item_category_checkbox)

# Adicionalmente, você pode adicionar gráficos ou outros elementos visuais ao seu dashboard usando o matplotlib ou outras bibliotecas.
# Por exemplo, plotar um gráfico de barras para a contagem de categorias:
plt.figure(figsize=(10, 6))
df['Item Category'].value_counts().plot(kind='bar')
plt.title('Contagem de Item Categories')
plt.xlabel('Item Category')
plt.ylabel('Contagem')
plt.show()
# Out:
# interactive(children=(Checkbox(value=True, description='Employee ID'), Checkbox(value=True, description='Emplo…
